# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
# Out:
# C:\Users\navya\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
pip install --upgrade pandas seaborn
# Out:
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.2
#     Uninstalling seaborn-0.11.2:
#       Successfully uninstalled seaborn-0.11.2
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
polls_data=pd.read_csv("C:/Users/navya/OneDrive/Documents/Project-Election/dataset/president_primary_polls.csv")
# Out:
# C:\Users\navya\AppData\Local\Temp\ipykernel_25140\2016983044.py:1: DtypeWarning: Columns (19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   polls_data=pd.read_csv("C:/Users/navya/OneDrive/Documents/Project-Election/dataset/president_primary_polls.csv")

# %%
polls_data.tail()
# Out:
#        poll_id  pollster_id  pollster sponsor_ids sponsors  \
# 22424    68055         1575     Leger         NaN      NaN
# 22425    68055         1575     Leger         NaN      NaN
# 22426    74404          147  Fabrizio         NaN      NaN
# 22427    74404          147  Fabrizio         NaN      NaN
# 22428    74404          147  Fabrizio         NaN      NaN
#
#                      display_name  pollster_rating_id  \
# 22424                       Leger                 572
# 22425                       Leger                 572
# 22426  Fabrizio, Lee & Associates                  90
# 22427  Fabrizio, Lee & Associates                  90
# 22428  Fabrizio, Lee & Associates                  90
#
#              pollster_rating_name  numeric_grade  pollscore  ...  \
# 22424                       Leger            2.0        0.0  ...
# 22425                       Leger            2.0        0.0  ...
# 22426  Fabrizio, Lee & Associates            1.7       -0.1  ...
# ...

# %%
plt.scatter(polls_data['party'],polls_data['answer'])
plt.show()

# %%
polls_data.plot(kind='scatter', x='party', y='pollster_rating_id')
# Out:
# <AxesSubplot:xlabel='party', ylabel='pollster_rating_id'>

# %%
polls_data.columns
# Out:
# Index(['poll_id', 'pollster_id', 'pollster', 'sponsor_ids', 'sponsors',
#        'display_name', 'pollster_rating_id', 'pollster_rating_name',
#        'numeric_grade', 'pollscore', 'methodology', 'transparency_score',
#        'state', 'start_date', 'end_date', 'sponsor_candidate_id',
#        'sponsor_candidate', 'sponsor_candidate_party', 'endorsed_candidate_id',
#        'endorsed_candidate_name', 'endorsed_candidate_party', 'question_id',
#        'sample_size', 'population', 'subpopulation', 'population_full',
#        'tracking', 'created_at', 'notes', 'url', 'url_article', 'url_topline',
#        'url_crosstab', 'source', 'internal', 'partisan', 'race_id', 'cycle',
#        'office_type', 'seat_number', 'seat_name', 'election_date', 'stage',
#        'nationwide_batch', 'ranked_choice_reallocated', 'ranked_choice_round',
#        'party', 'answer', 'candidate_id', 'candidate_name', 'pct'],
#       dtype='object')

# %%
df_group = polls_data[['poll_id', 'pollster_id', 'pollster', 'sponsor_ids', 'sponsors',
       'display_name', 'pollster_rating_id', 'pollster_rating_name',
       'numeric_grade', 'pollscore', 'methodology', 'transparency_score',
       'state', 'start_date', 'end_date', 'sponsor_candidate_id',
       'sponsor_candidate', 'sponsor_candidate_party', 'endorsed_candidate_id',
       'endorsed_candidate_name', 'endorsed_candidate_party', 'question_id',
       'sample_size', 'population', 'subpopulation', 'population_full',
       'tracking', 'created_at', 'notes', 'url', 'url_article', 'url_topline',
       'url_crosstab', 'source', 'internal', 'partisan', 'race_id', 'cycle',
       'office_type', 'seat_number', 'seat_name', 'election_date', 'stage',
       'nationwide_batch', 'ranked_choice_reallocated', 'ranked_choice_round',
       'party', 'answer', 'candidate_id', 'candidate_name', 'pct']]

# %%
polls_data.dtypes
# Out:
# poll_id                        int64
# pollster_id                    int64
# pollster                      object
# sponsor_ids                   object
# sponsors                      object
# display_name                  object
# pollster_rating_id             int64
# pollster_rating_name          object
# numeric_grade                float64
# pollscore                    float64
# methodology                   object
# transparency_score           float64
# state                         object
# start_date                    object
# end_date                      object
# sponsor_candidate_id         float64
# sponsor_candidate             object
# sponsor_candidate_party       object
# endorsed_candidate_id        float64
# endorsed_candidate_name       object
# endorsed_candidate_party      object
# question_id                    int64
# sample_size                  float64
# population                    object
# subpopulation                 object
# ...

# %%
polls_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22429 entries, 0 to 22428
# Data columns (total 51 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   poll_id                    22429 non-null  int64
#  1   pollster_id                22429 non-null  int64
#  2   pollster                   22429 non-null  object
#  3   sponsor_ids                6248 non-null   object
#  4   sponsors                   6248 non-null   object
#  5   display_name               22429 non-null  object
#  6   pollster_rating_id         22429 non-null  int64
#  7   pollster_rating_name       22429 non-null  object
#  8   numeric_grade              21854 non-null  float64
#  9   pollscore                  21876 non-null  float64
#  10  methodology                21817 non-null  object
#  11  transparency_score         8220 non-null   float64
#  12  state                      7419 non-null   object
# ...

# %%
polls_data.dropna(inplace=True)

# %%
polls_data.fillna(method='ffill', inplace=True)  # Forward fill
polls_data.fillna(polls_data.mean(), inplace=True)       # Fill with mean
# Out:
# C:\Users\navya\AppData\Local\Temp\ipykernel_25140\970834524.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   polls_data.fillna(method='ffill', inplace=True)  # Forward fill

# %%
polls_data.isna()
# Out:
# Empty DataFrame
# Columns: [poll_id, pollster_id, pollster, sponsor_ids, sponsors, display_name, pollster_rating_id, pollster_rating_name, numeric_grade, pollscore, methodology, transparency_score, state, start_date, end_date, sponsor_candidate_id, sponsor_candidate, sponsor_candidate_party, endorsed_candidate_id, endorsed_candidate_name, endorsed_candidate_party, question_id, sample_size, population, subpopulation, population_full, tracking, created_at, notes, url, url_article, url_topline, url_crosstab, source, internal, partisan, race_id, cycle, office_type, seat_number, seat_name, election_date, stage, nationwide_batch, ranked_choice_reallocated, ranked_choice_round, party, answer, candidate_id, candidate_name, pct]
# Index: []
#
# [0 rows x 51 columns]

# %%
polls_data.head()
# Out:
#    poll_id  pollster_id pollster sponsor_ids                     sponsors  \
# 0    87555          568   YouGov   2167,2168  The Times of London | SAY24
# 1    87555          568   YouGov   2167,2168  The Times of London | SAY24
# 2    87555          568   YouGov   2167,2168  The Times of London | SAY24
# 3    87555          568   YouGov   2167,2168  The Times of London | SAY24
# 4    87555          568   YouGov   2167,2168  The Times of London | SAY24
#
#   display_name  pollster_rating_id pollster_rating_name  numeric_grade  \
# 0       YouGov                 391               YouGov            3.0
# 1       YouGov                 391               YouGov            3.0
# 2       YouGov                 391               YouGov            3.0
# 3       YouGov                 391               YouGov            3.0
# 4       YouGov                 391               YouGov            3.0
#
#    pollscore  ... election_date    stage nationwide_batch  \
# ...

# %%
# Filter for Donald Trump and Kamala Harris
candidates = ['Donald Trump', 'Kamala Harris']
filtered_df = polls_data[polls_data['candidate_name'].isin(candidates)]
df=polls_data

# %%
# Define the candidates you want to focus on
target_candidates = ['Donald Trump', 'Kamala Harris']

# Create a new column 'candidate_group' to categorize candidates
df['candidate_group'] = df['candidate_name'].apply(
    lambda x: x if x in target_candidates else 'Others'
)

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [poll_id, pollster_id, pollster, sponsor_ids, sponsors, display_name, pollster_rating_id, pollster_rating_name, numeric_grade, pollscore, methodology, transparency_score, state, start_date, end_date, sponsor_candidate_id, sponsor_candidate, sponsor_candidate_party, endorsed_candidate_id, endorsed_candidate_name, endorsed_candidate_party, question_id, sample_size, population, subpopulation, population_full, tracking, created_at, notes, url, url_article, url_topline, url_crosstab, source, internal, partisan, race_id, cycle, office_type, seat_number, seat_name, election_date, stage, nationwide_batch, ranked_choice_reallocated, ranked_choice_round, party, answer, candidate_id, candidate_name, pct, candidate_group]
# Index: []
#
# [0 rows x 52 columns]

# %%
polls_df=pd.read_csv("C:/Users/navya/OneDrive/Documents/Project-Election/dataset/president_primary_polls.csv")
# Out:
# C:\Users\navya\AppData\Local\Temp\ipykernel_25140\2067197001.py:1: DtypeWarning: Columns (19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   polls_df=pd.read_csv("C:/Users/navya/OneDrive/Documents/Project-Election/dataset/president_primary_polls.csv")

# %%
# Define the candidates you want to focus on
target_candidates = ['Donald Trump', 'Kamala Harris']

# Create a new column 'candidate_group' to categorize candidates
polls_df['candidate_group'] = polls_df['candidate_name'].apply(
    lambda x: x if x in target_candidates else 'Others'
)

# %%
polls_df.head()
# Out:
#    poll_id  pollster_id pollster sponsor_ids                     sponsors  \
# 0    87555          568   YouGov   2167,2168  The Times of London | SAY24
# 1    87555          568   YouGov   2167,2168  The Times of London | SAY24
# 2    87555          568   YouGov   2167,2168  The Times of London | SAY24
# 3    87555          568   YouGov   2167,2168  The Times of London | SAY24
# 4    87555          568   YouGov   2167,2168  The Times of London | SAY24
#
#   display_name  pollster_rating_id pollster_rating_name  numeric_grade  \
# 0       YouGov                 391               YouGov            3.0
# 1       YouGov                 391               YouGov            3.0
# 2       YouGov                 391               YouGov            3.0
# 3       YouGov                 391               YouGov            3.0
# 4       YouGov                 391               YouGov            3.0
#
#    pollscore  ...    stage  nationwide_batch ranked_choice_reallocated  \
# ...

# %%
plt.scatter(polls_df['pct'],polls_df['candidate_group'])
plt.show()

# %%
plt.scatter(polls_df['subpopulation'],polls_df['candidate_group'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 plt.scatter(polls_df['subpopulation'],polls_df['candidate_group'])
#       2 plt.show()
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2807, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2802 @_copy_docstring_and_deprecators(Axes.scatter)
#    2803 def scatter(
#    2804         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2805         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2806         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2807     __ret = gca().scatter(
#    2808         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2809         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
# ...

# %%
polls_df['population']
# Out:
# 0        rv
# 1        rv
# 2        rv
# 3        rv
# 4        rv
#          ..
# 22424    lv
# 22425    lv
# 22426    lv
# 22427    lv
# 22428    lv
# Name: population, Length: 22429, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoders
population_encoder = LabelEncoder()
subpopulation_encoder = LabelEncoder()

# Encode population and subpopulation
polls_df['population_encoded'] = population_encoder.fit_transform(polls_df['population'].fillna('Unknown'))
polls_df['subpopulation_encoded'] = subpopulation_encoder.fit_transform(polls_df['subpopulation'].fillna('Unknown'))

# %%
polls_df['subpopulation_encoded']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 22424    0
# 22425    0
# 22426    2
# 22427    2
# 22428    2
# Name: subpopulation_encoded, Length: 22429, dtype: int32

# %%
# Scatter plot for population vs subpopulation, colored by candidate_group
plt.figure(figsize=(10, 6))

# Create scatter plot for each candidate group
for candidate in polls_df['candidate_group'].unique():
    candidate_data = polls_df[polls_df['candidate_group'] == candidate]
    plt.scatter(
        candidate_data['population_encoded'], 
        candidate_data['subpopulation_encoded'], 
        label=candidate, 
        alpha=0.5
    )

# Add labels and title
plt.xlabel('Population')
plt.ylabel('Subpopulation')
plt.title('Comparison of Population and Subpopulation by Candidate Group')
plt.legend()
plt.xticks(ticks=range(len(population_encoder.classes_)), labels=population_encoder.classes_)
plt.yticks(ticks=range(len(subpopulation_encoder.classes_)), labels=subpopulation_encoder.classes_)
plt.grid(True)
plt.show()

# %%
plt.scatter(polls_df['subpopulation_encoded'],polls_df['candidate_group'])
plt.show()

# %%
plt.scatter(polls_df['population_encoded'],polls_df['candidate_group'])
plt.show()

# %%
plt.scatter(polls_df['answer'],polls_df['candidate_group'])
plt.show()

# %%
polls_df['answer']
# Out:
# 0            Harris
# 1           Whitmer
# 2            Newsom
# 3         Buttigieg
# 4           Shapiro
#             ...
# 22424        Abrams
# 22425    Gillibrand
# 22426      DeSantis
# 22427         Rubio
# 22428      R. Scott
# Name: answer, Length: 22429, dtype: object

# %%
polling_data = polls_df[['candidate_group', 'answer', 'pct']]

# Create a bar plot comparing candidate_name and answer
plt.figure(figsize=(12, 6))
sns.barplot(x='candidate_group', y='pct', hue='answer', data=polling_data, ci=None)

# Add labels and title
plt.xlabel('Candidate Being Polled')
plt.ylabel('Polling Percentage (%)')
plt.title('Polling Percentage by Candidate and Respondent Answer')
plt.xticks(rotation=45)
plt.legend(title='Answer (Respondent Supported Candidate)', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
target_answers = ['Trump', 'Harris']

# Create a new column 'candidate_group' to categorize candidates
polls_df['target_answer'] = polls_df['answer'].apply(
    lambda x: x if x in target_answers else 'Others'
)

# %%
polling_data = polls_df[['candidate_group', 'target_answer', 'pct']]

# Create a bar plot comparing candidate_name and answer
plt.figure(figsize=(12, 6))
sns.barplot(x='candidate_group', y='pct', hue='target_answer', data=polling_data, ci=None)

# Add labels and title
plt.xlabel('Candidate Being Polled')
plt.ylabel('Polling Percentage (%)')
plt.title('Polling Percentage by Candidate and Respondent Answer')
plt.xticks(rotation=45)
plt.legend(title='Answer (Respondent Supported Candidate)', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
size_population_data = polls_df[['sample_size', 'population', 'subpopulation']]

# Create a bar plot comparing candidate_name and answer
plt.figure(figsize=(12, 6))
sns.barplot(x='sample_size', y='population', hue='subpopulation', data=size_population_data, ci=None)

# Add labels and title
plt.xlabel('sample size')
plt.ylabel('population of voters')
 #(lv-Likely voters , rv-registered voters, a-adults, v-voters)
plt.title('No.of people opting for Democratic or Republic')
plt.xticks(rotation=45)
plt.legend(title='subpopulation', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
# Create a bar plot to compare pollscore by pollster
plt.figure(figsize=(12, 6))
sns.barplot(x='pollster', y='pollscore', data=polls_df, ci=None)

# Add labels and title
plt.xlabel('Pollster')
plt.ylabel('Poll Score')
plt.title('Poll Score by Pollster')
plt.xticks(rotation=90)
plt.show()

# %%
# Group by pollster and calculate the average pollscore
top_pollsters = polls_df.groupby('pollster')['pollscore'].mean().sort_values(ascending=False).head(10).index

# Filter the dataframe to include only the top 10 pollsters
df_top_pollsters = polls_df[polls_df['pollster'].isin(top_pollsters)]

# Create a bar plot for the top 10 pollsters
plt.figure(figsize=(12, 6))
sns.barplot(x='pollster', y='pollscore', data=df_top_pollsters, ci=None)

# Add labels and title
plt.xlabel('Pollster')
plt.ylabel('Poll Score')
plt.title('Top 10 Pollsters by Poll Score')
plt.xticks(rotation=45)
plt.show()

# %%
# Create a box plot to compare pollscore by methodology
# Group by pollster and calculate the average pollscore
top_methodology = polls_df.groupby('methodology')['pollscore'].mean().sort_values(ascending=False).head(10).index

# Filter the dataframe to include only the top 10 pollsters
df_top_methodology = polls_df[polls_df['methodology'].isin(top_pollsters)]

plt.figure(figsize=(12, 6))
sns.barplot(x='methodology', y='pollscore', data=df_top_methodology)

# Add labels and title
plt.xlabel('Methodology')
plt.ylabel('Poll Score')
plt.title('Poll Score by Methodology')
plt.xticks(rotation=90)
plt.show()

# %%
# Create a scatter plot to compare transparency_score vs pollscore
plt.figure(figsize=(10, 6))
sns.scatterplot(x='transparency_score', y='pollscore', hue='methodology', data=df_top_methodology)

# Add labels and title
plt.xlabel('Transparency Score')
plt.ylabel('Poll Score')
plt.title('Poll Score vs Transparency Score by Methodology')
plt.legend(title='methodology', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
